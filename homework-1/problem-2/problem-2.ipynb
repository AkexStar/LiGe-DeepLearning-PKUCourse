# %% [markdown]
# ## 平时作业（1）：多层神经网络的训练
#
# - 李锦韬 2201213292
#
# ### 作业要求
#
# **请根据自己的计算环境情况和兴趣，选择以下两个数据集之一，完成如下的实验：**
# - http://yann.lecun.com/exdb/mnist/
# - https://www.cs.toronto.edu/~kriz/cifar.html
#
# **1. 构造一个多层的神经网络（注意，不要使用卷积神经网络，本题目要求使用多层神经网络），并在上述数据集任务上进行训练，并汇报一个“使用了你认为最优的超参数配置的神经网络”的学习曲线；要求如下：**
# * （1）自己手动完成反向传播算法部分的编写；
# * （2）该网络应为一个“纯净”的多层神经网络，不使用正则化方法、率优化算法等；
#
# **2. 在上述“你认为最优配置的神经网络”的基础上，**
# * （1）分别汇报“增加一个隐藏层”和“减小一个隐藏层”情况下的学习曲线；
# * （2）分别汇报使用BGD和SGD进行训练的学习曲线；
# * （3）分别汇报使用两种以上参数初始化方法下的学习曲线；
# * （4）分别汇报使用两种以上学习率优化算法下的学习曲线；
# * （5）分别汇报使用两种以上正则化方法下的学习曲线；
#
# **最终提交：包含6个子文件夹的一个zip文件，其中的子文件夹应包含：**
# * （1）对应上述6种情况之一的一份源代码；
# * （2）对应上述源代码的学习曲线的一个.png文件；

# %% [markdown]
# ## 2. 隐藏层的增加与减少

# %% [markdown]
# ### 2.0 原始网络
# - 网络结构（每层神经元个数）：784-128-64-10

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1]
hidden_size_1 = 128
hidden_size_2 = 64
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size)
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, hidden_size_2) / np.sqrt(hidden_size_1)
b2 = np.zeros(hidden_size_2)
W3 = np.random.randn(hidden_size_2, output_size) / np.sqrt(hidden_size_2)
b3 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, W3, b1, b2, b3
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W3 = 1./m*np.dot(a2.T, grad_y_pred)
    grad_b3 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a2 = np.dot(grad_y_pred, W3.T)

    grad_z2 = grad_a2.copy()
    grad_z2[z2 < 0] = 0
    grad_W2 = 1./m*np.dot(a1.T, grad_z2)
    grad_b2 = 1./m*np.sum(grad_z2, axis=0)
    grad_a1 = np.dot(grad_z2, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W3 -= learning_rate * grad_W3
    b3 -= learning_rate * grad_b3
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, W3, b1, b2, b3
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.1
num_epochs = 30
batch_size = 64
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history0 = []
test_acc_history0 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]
    for i in range(num_batches):
        # 从训练数据中随机抽取一个batch
        X_batch = X_train[i * batch_size:(i + 1) * batch_size]
        y_batch = y_train[i * batch_size:(i + 1) * batch_size]

        # 训练一个batch，并记录损失函数值
        loss = train(X_batch, y_batch, learning_rate)
        train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history0.append(train_acc)
    test_acc_history0.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))

plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history0, label='train')
plt.plot(test_acc_history0, label='test')
plt.title('Classification Accuracy 784-128-64-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/30, train loss: 0.071023, train acc: 0.968117, test acc: 0.961400
# Epoch 2/30, train loss: 0.116831, train acc: 0.980267, test acc: 0.970500
# Epoch 3/30, train loss: 0.039256, train acc: 0.984600, test acc: 0.974800
# Epoch 4/30, train loss: 0.060885, train acc: 0.983950, test acc: 0.972900
# Epoch 5/30, train loss: 0.004422, train acc: 0.991917, test acc: 0.976900
# Epoch 6/30, train loss: 0.012613, train acc: 0.992900, test acc: 0.977000
# Epoch 7/30, train loss: 0.016745, train acc: 0.994667, test acc: 0.977600
# Epoch 8/30, train loss: 0.008910, train acc: 0.995433, test acc: 0.977800
# Epoch 9/30, train loss: 0.225081, train acc: 0.994883, test acc: 0.977800
# Epoch 10/30, train loss: 0.063704, train acc: 0.997567, test acc: 0.980400
# Epoch 11/30, train loss: 0.000962, train acc: 0.999350, test acc: 0.981900
# Epoch 12/30, train loss: 0.006435, train acc: 0.999767, test acc: 0.982400
# Epoch 13/30, train loss: 0.001063, train acc: 0.999933, test acc: 0.983200
# Epoch 14/30, train loss: 0.002925, train acc: 0.999983, test acc: 0.982900
# Epoch 15/30, train loss: 0.001134, train acc: 0.999983, test acc: 0.982700
# Epoch 16/30, train loss: 0.000847, train acc: 1.000000, test acc: 0.983700
# Epoch 17/30, train loss: 0.000221, train acc: 1.000000, test acc: 0.983500
# Epoch 18/30, train loss: 0.001652, train acc: 0.999983, test acc: 0.983000
# Epoch 19/30, train loss: 0.000123, train acc: 1.000000, test acc: 0.983400
# Epoch 20/30, train loss: 0.000445, train acc: 1.000000, test acc: 0.983200
# Epoch 21/30, train loss: 0.000445, train acc: 1.000000, test acc: 0.983100
# Epoch 22/30, train loss: 0.000865, train acc: 1.000000, test acc: 0.983200
# Epoch 23/30, train loss: 0.000303, train acc: 1.000000, test acc: 0.983400
# Epoch 24/30, train loss: 0.000248, train acc: 1.000000, test acc: 0.983300
# Epoch 25/30, train loss: 0.000092, train acc: 1.000000, test acc: 0.983300
# Epoch 26/30, train loss: 0.000199, train acc: 1.000000, test acc: 0.983700
# Epoch 27/30, train loss: 0.000356, train acc: 1.000000, test acc: 0.982900
# Epoch 28/30, train loss: 0.000890, train acc: 1.000000, test acc: 0.983300
# Epoch 29/30, train loss: 0.000542, train acc: 1.000000, test acc: 0.982900
# Epoch 30/30, train loss: 0.000711, train acc: 1.000000, test acc: 0.983800

# %% [markdown]
# ### 2.1 增加隐藏层
# - 网络结构（每层神经元个数）：784-128-64-64-10

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1] # 784
hidden_size_1 = 128
hidden_size_2 = 64
hidden_size_3 = 64
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size) 
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, hidden_size_2) / np.sqrt(hidden_size_1)
b2 = np.zeros(hidden_size_2)
W3 = np.random.randn(hidden_size_2, hidden_size_3) / np.sqrt(hidden_size_2)
b3 = np.zeros(hidden_size_3)
W4 = np.random.randn(hidden_size_3, output_size) / np.sqrt(hidden_size_3)
b4 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, W3, W4, b1, b2, b3, b4
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    a3 = relu(z3)
    z4 = np.dot(a3, W4) + b4
    y_pred = softmax(z4)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W4 = 1./m*np.dot(a3.T, grad_y_pred)
    grad_b4 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a3 = np.dot(grad_y_pred, W4.T)

    grad_z3 = grad_a3.copy()
    grad_z3[z3 < 0] = 0
    grad_W3 = 1./m*np.dot(a2.T, grad_z3)
    grad_b3 = 1./m*np.sum(grad_z3, axis=0)
    grad_a2 = np.dot(grad_z3, W3.T)

    grad_z2 = grad_a2.copy()
    grad_z2[z2 < 0] = 0
    grad_W2 = 1./m*np.dot(a1.T, grad_z2)
    grad_b2 = 1./m*np.sum(grad_z2, axis=0)
    grad_a1 = np.dot(grad_z2, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W4 -= learning_rate * grad_W4
    b4 -= learning_rate * grad_b4
    W3 -= learning_rate * grad_W3
    b3 -= learning_rate * grad_b3
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, W3, W4, b1, b2, b3, b4
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    a3 = relu(z3)
    z4 = np.dot(a3, W4) + b4
    y_pred = softmax(z4)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.1
num_epochs = 30
batch_size = 64
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history1 = []
test_acc_history1 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]
    for i in range(num_batches):
        # 从训练数据中随机抽取一个batch
        X_batch = X_train[i * batch_size:(i + 1) * batch_size]
        y_batch = y_train[i * batch_size:(i + 1) * batch_size]

        # 训练一个batch，并记录损失函数值
        loss = train(X_batch, y_batch, learning_rate)
        train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history1.append(train_acc)
    test_acc_history1.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))

plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history1, label='train')
plt.plot(test_acc_history1, label='test')
plt.title('Classification Accuracy 784-128-64-64-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/30, train loss: 0.118690, train acc: 0.969817, test acc: 0.964100
# Epoch 2/30, train loss: 0.160553, train acc: 0.976367, test acc: 0.967800
# Epoch 3/30, train loss: 0.141817, train acc: 0.981283, test acc: 0.968200
# Epoch 4/30, train loss: 0.061499, train acc: 0.984950, test acc: 0.970500
# Epoch 5/30, train loss: 0.180780, train acc: 0.987417, test acc: 0.971700
# Epoch 6/30, train loss: 0.033794, train acc: 0.991933, test acc: 0.976700
# Epoch 7/30, train loss: 0.036607, train acc: 0.993317, test acc: 0.973300
# Epoch 8/30, train loss: 0.014058, train acc: 0.995617, test acc: 0.976100
# Epoch 9/30, train loss: 0.003247, train acc: 0.998017, test acc: 0.977800
# Epoch 10/30, train loss: 0.001002, train acc: 0.997467, test acc: 0.977000
# Epoch 11/30, train loss: 0.003958, train acc: 0.993900, test acc: 0.974200
# Epoch 12/30, train loss: 0.035608, train acc: 0.996233, test acc: 0.976700
# Epoch 13/30, train loss: 0.041613, train acc: 0.998100, test acc: 0.977700
# Epoch 14/30, train loss: 0.001065, train acc: 0.999133, test acc: 0.978900
# Epoch 15/30, train loss: 0.000123, train acc: 0.999917, test acc: 0.980200
# Epoch 16/30, train loss: 0.000005, train acc: 0.999900, test acc: 0.980900
# Epoch 17/30, train loss: 0.000209, train acc: 1.000000, test acc: 0.980300
# Epoch 18/30, train loss: 0.001643, train acc: 1.000000, test acc: 0.980300
# Epoch 19/30, train loss: 0.000141, train acc: 1.000000, test acc: 0.980200
# Epoch 20/30, train loss: 0.000118, train acc: 1.000000, test acc: 0.980600
# Epoch 21/30, train loss: 0.000076, train acc: 1.000000, test acc: 0.980300
# Epoch 22/30, train loss: 0.000068, train acc: 1.000000, test acc: 0.980400
# Epoch 23/30, train loss: 0.000007, train acc: 1.000000, test acc: 0.980400
# Epoch 24/30, train loss: 0.000020, train acc: 1.000000, test acc: 0.980500
# Epoch 25/30, train loss: 0.000028, train acc: 1.000000, test acc: 0.980400
# Epoch 26/30, train loss: 0.000296, train acc: 1.000000, test acc: 0.980900
# Epoch 27/30, train loss: 0.000098, train acc: 1.000000, test acc: 0.980700
# Epoch 28/30, train loss: 0.000029, train acc: 1.000000, test acc: 0.980400
# Epoch 29/30, train loss: 0.000150, train acc: 1.000000, test acc: 0.980300
# Epoch 30/30, train loss: 0.000007, train acc: 1.000000, test acc: 0.980500

# %% [markdown]
# ### 2.2 减少隐藏层
# - 网络结构（每层神经元个数）：784-128-10

# %%
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1]
hidden_size_1 = 128
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size)
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, output_size) / np.sqrt(hidden_size_1)
b2 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, b1, b2
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    y_pred = softmax(z2)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W2 = 1./m*np.dot(a1.T, grad_y_pred)
    grad_b2 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a1 = np.dot(grad_y_pred, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, b1, b2
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    y_pred = softmax(z2)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.1
num_epochs = 30
batch_size = 64
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history2 = []
test_acc_history2 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]
    for i in range(num_batches):
        # 从训练数据中随机抽取一个batch
        X_batch = X_train[i * batch_size:(i + 1) * batch_size]
        y_batch = y_train[i * batch_size:(i + 1) * batch_size]

        # 训练一个batch，并记录损失函数值
        loss = train(X_batch, y_batch, learning_rate)
        train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history2.append(train_acc)
    test_acc_history2.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))

plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history2, label='train')
plt.plot(test_acc_history2, label='test')
plt.title('Classification Accuracy 784-128-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/30, train loss: 0.073684, train acc: 0.967317, test acc: 0.963100
# Epoch 2/30, train loss: 0.128020, train acc: 0.977717, test acc: 0.970800
# Epoch 3/30, train loss: 0.024692, train acc: 0.985750, test acc: 0.975900
# Epoch 4/30, train loss: 0.016530, train acc: 0.987850, test acc: 0.975600
# Epoch 5/30, train loss: 0.066118, train acc: 0.988717, test acc: 0.974100
# Epoch 6/30, train loss: 0.015977, train acc: 0.993400, test acc: 0.979400
# Epoch 7/30, train loss: 0.012982, train acc: 0.994583, test acc: 0.978900
# Epoch 8/30, train loss: 0.003754, train acc: 0.996200, test acc: 0.980200
# Epoch 9/30, train loss: 0.021625, train acc: 0.997317, test acc: 0.979700
# Epoch 10/30, train loss: 0.005823, train acc: 0.998583, test acc: 0.980600
# Epoch 11/30, train loss: 0.004097, train acc: 0.997900, test acc: 0.980600
# Epoch 12/30, train loss: 0.003182, train acc: 0.999317, test acc: 0.980600
# Epoch 13/30, train loss: 0.006515, train acc: 0.999417, test acc: 0.981700
# Epoch 14/30, train loss: 0.002720, train acc: 0.999783, test acc: 0.981800
# Epoch 15/30, train loss: 0.004612, train acc: 0.999800, test acc: 0.981600
# Epoch 16/30, train loss: 0.003819, train acc: 0.999883, test acc: 0.981800
# Epoch 17/30, train loss: 0.001123, train acc: 0.999867, test acc: 0.981500
# Epoch 18/30, train loss: 0.002403, train acc: 0.999917, test acc: 0.981000
# Epoch 19/30, train loss: 0.003001, train acc: 0.999983, test acc: 0.981400
# Epoch 20/30, train loss: 0.003783, train acc: 1.000000, test acc: 0.980800
# Epoch 21/30, train loss: 0.004265, train acc: 0.999967, test acc: 0.982200
# Epoch 22/30, train loss: 0.001000, train acc: 1.000000, test acc: 0.981400
# Epoch 23/30, train loss: 0.001188, train acc: 0.999983, test acc: 0.981400
# Epoch 24/30, train loss: 0.001330, train acc: 1.000000, test acc: 0.981200
# Epoch 25/30, train loss: 0.004392, train acc: 1.000000, test acc: 0.982000
# Epoch 26/30, train loss: 0.001299, train acc: 1.000000, test acc: 0.982100
# Epoch 27/30, train loss: 0.000189, train acc: 1.000000, test acc: 0.982000
# Epoch 28/30, train loss: 0.001368, train acc: 1.000000, test acc: 0.982000
# Epoch 29/30, train loss: 0.000621, train acc: 1.000000, test acc: 0.981700
# Epoch 30/30, train loss: 0.000125, train acc: 1.000000, test acc: 0.981200

# %% [markdown]
# ## 学习曲线对比

# %%
# plt.plot(train_acc_history0, label='train-mid')
plt.plot(test_acc_history0, label='test-mid 784-128-64-10')
# plt.plot(train_acc_history1, label='train-deep')
plt.plot(test_acc_history1, label='test-deep 784-128-64-64-10')
# plt.plot(train_acc_history2, label='train-shallow')
plt.plot(test_acc_history2, label='test-shallow 784-128-10')
plt.title('different hidden-layer numbers')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('different hidden-layer numbers.png')
plt.show()
