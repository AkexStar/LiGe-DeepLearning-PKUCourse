# %% [markdown]
# ## 平时作业（1）：多层神经网络的训练
#
# - 李锦韬 2201213292
#
# ### 作业要求
#
# **请根据自己的计算环境情况和兴趣，选择以下两个数据集之一，完成如下的实验：**
# - http://yann.lecun.com/exdb/mnist/
# - https://www.cs.toronto.edu/~kriz/cifar.html
#
# **1. 构造一个多层的神经网络（注意，不要使用卷积神经网络，本题目要求使用多层神经网络），并在上述数据集任务上进行训练，并汇报一个“使用了你认为最优的超参数配置的神经网络”的学习曲线；要求如下：**
# * （1）自己手动完成反向传播算法部分的编写；
# * （2）该网络应为一个“纯净”的多层神经网络，不使用正则化方法、率优化算法等；
#
# **2. 在上述“你认为最优配置的神经网络”的基础上，**
# * （1）分别汇报“增加一个隐藏层”和“减小一个隐藏层”情况下的学习曲线；
# * （2）分别汇报使用BGD和SGD进行训练的学习曲线；
# * （3）分别汇报使用两种以上参数初始化方法下的学习曲线；
# * （4）分别汇报使用两种以上学习率优化算法下的学习曲线；
# * （5）分别汇报使用两种以上正则化方法下的学习曲线；
#
# **最终提交：包含6个子文件夹的一个zip文件，其中的子文件夹应包含：**
# * （1）对应上述6种情况之一的一份源代码；
# * （2）对应上述源代码的学习曲线的一个.png文件；

# %% [markdown]
# ## 3. BGD与SGD

# %% [markdown]
# ### 3.0 MBGD小批量梯度下降

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1]
hidden_size_1 = 128
hidden_size_2 = 64
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size)
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, hidden_size_2) / np.sqrt(hidden_size_1)
b2 = np.zeros(hidden_size_2)
W3 = np.random.randn(hidden_size_2, output_size) / np.sqrt(hidden_size_2)
b3 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, W3, b1, b2, b3
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W3 = 1./m*np.dot(a2.T, grad_y_pred)
    grad_b3 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a2 = np.dot(grad_y_pred, W3.T)

    grad_z2 = grad_a2.copy()
    grad_z2[z2 < 0] = 0
    grad_W2 = 1./m*np.dot(a1.T, grad_z2)
    grad_b2 = 1./m*np.sum(grad_z2, axis=0)
    grad_a1 = np.dot(grad_z2, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W3 -= learning_rate * grad_W3
    b3 -= learning_rate * grad_b3
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, W3, b1, b2, b3
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.1
num_epochs = 40
batch_size = 64
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history0 = []
test_acc_history0 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]
    for i in range(num_batches):
        # 从训练数据中随机抽取一个batch
        X_batch = X_train[i * batch_size:(i + 1) * batch_size]
        y_batch = y_train[i * batch_size:(i + 1) * batch_size]

        # 训练一个batch，并记录损失函数值
        loss = train(X_batch, y_batch, learning_rate)
        train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history0.append(train_acc)
    test_acc_history0.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))


plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history0, label='train')
plt.plot(test_acc_history0, label='test')
plt.title('Classification Accuracy MBGD')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/40, train loss: 0.139667, train acc: 0.966983, test acc: 0.964000
# Epoch 2/40, train loss: 0.043296, train acc: 0.977600, test acc: 0.969900
# Epoch 3/40, train loss: 0.012706, train acc: 0.985567, test acc: 0.975600
# Epoch 4/40, train loss: 0.028891, train acc: 0.984617, test acc: 0.969700
# Epoch 5/40, train loss: 0.106398, train acc: 0.992283, test acc: 0.977500
# Epoch 6/40, train loss: 0.107069, train acc: 0.993817, test acc: 0.977400
# Epoch 7/40, train loss: 0.003890, train acc: 0.995000, test acc: 0.976500
# Epoch 8/40, train loss: 0.008793, train acc: 0.995633, test acc: 0.977100
# Epoch 9/40, train loss: 0.001978, train acc: 0.996133, test acc: 0.977300
# Epoch 10/40, train loss: 0.000784, train acc: 0.998067, test acc: 0.978600
# Epoch 11/40, train loss: 0.002287, train acc: 0.999133, test acc: 0.981200
# Epoch 12/40, train loss: 0.002830, train acc: 0.999267, test acc: 0.979000
# Epoch 13/40, train loss: 0.013382, train acc: 0.999733, test acc: 0.979900
# Epoch 14/40, train loss: 0.003189, train acc: 0.999867, test acc: 0.981600
# Epoch 15/40, train loss: 0.000785, train acc: 0.996767, test acc: 0.978700
# Epoch 16/40, train loss: 0.001269, train acc: 1.000000, test acc: 0.981100
# Epoch 17/40, train loss: 0.000449, train acc: 1.000000, test acc: 0.981500
# Epoch 18/40, train loss: 0.000192, train acc: 1.000000, test acc: 0.981500
# Epoch 19/40, train loss: 0.000049, train acc: 1.000000, test acc: 0.981100
# Epoch 20/40, train loss: 0.001077, train acc: 1.000000, test acc: 0.980900
# Epoch 21/40, train loss: 0.000297, train acc: 1.000000, test acc: 0.981200
# Epoch 22/40, train loss: 0.000522, train acc: 1.000000, test acc: 0.981500
# Epoch 23/40, train loss: 0.000845, train acc: 1.000000, test acc: 0.981300
# Epoch 24/40, train loss: 0.000151, train acc: 1.000000, test acc: 0.981500
# Epoch 25/40, train loss: 0.000275, train acc: 1.000000, test acc: 0.981300
# Epoch 26/40, train loss: 0.000517, train acc: 1.000000, test acc: 0.981400
# Epoch 27/40, train loss: 0.000466, train acc: 1.000000, test acc: 0.981200
# Epoch 28/40, train loss: 0.000592, train acc: 1.000000, test acc: 0.981300
# Epoch 29/40, train loss: 0.000290, train acc: 1.000000, test acc: 0.981500
# Epoch 30/40, train loss: 0.000106, train acc: 1.000000, test acc: 0.981100
# Epoch 31/40, train loss: 0.000081, train acc: 1.000000, test acc: 0.981100
# Epoch 32/40, train loss: 0.000047, train acc: 1.000000, test acc: 0.981300
# Epoch 33/40, train loss: 0.000145, train acc: 1.000000, test acc: 0.981700
# Epoch 34/40, train loss: 0.000031, train acc: 1.000000, test acc: 0.981100
# Epoch 35/40, train loss: 0.000964, train acc: 1.000000, test acc: 0.981200
# Epoch 36/40, train loss: 0.000137, train acc: 1.000000, test acc: 0.981200
# Epoch 37/40, train loss: 0.000079, train acc: 1.000000, test acc: 0.981200
# Epoch 38/40, train loss: 0.000087, train acc: 1.000000, test acc: 0.981300
# Epoch 39/40, train loss: 0.000195, train acc: 1.000000, test acc: 0.981100
# Epoch 40/40, train loss: 0.000213, train acc: 1.000000, test acc: 0.981000

# %% [markdown]
# ### 3.1 BGD批量梯度下降

# %%
import numpy as np
import pickle
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1]
hidden_size_1 = 128
hidden_size_2 = 64
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size)
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, hidden_size_2) / np.sqrt(hidden_size_1)
b2 = np.zeros(hidden_size_2)
W3 = np.random.randn(hidden_size_2, output_size) / np.sqrt(hidden_size_2)
b3 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, W3, b1, b2, b3
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W3 = 1./m*np.dot(a2.T, grad_y_pred)
    grad_b3 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a2 = np.dot(grad_y_pred, W3.T)

    grad_z2 = grad_a2.copy()
    grad_z2[z2 < 0] = 0
    grad_W2 = 1./m*np.dot(a1.T, grad_z2)
    grad_b2 = 1./m*np.sum(grad_z2, axis=0)
    grad_a1 = np.dot(grad_z2, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W3 -= learning_rate * grad_W3
    b3 -= learning_rate * grad_b3
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, W3, b1, b2, b3
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.08
num_epochs = 40
batch_size = X_train.shape[0]
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history1 = []
test_acc_history1 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]

    # 记录损失函数值
    loss = train(X_train, y_train, learning_rate)
    train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history1.append(train_acc)
    test_acc_history1.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))

plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history1, label='train')
plt.plot(test_acc_history1, label='test')
plt.title('Classification Accuracy BGD')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/40, train loss: 2.374732, train acc: 0.217167, test acc: 0.213900
# Epoch 2/40, train loss: 2.222260, train acc: 0.313350, test acc: 0.313600
# Epoch 3/40, train loss: 2.104126, train acc: 0.403567, test acc: 0.408300
# Epoch 4/40, train loss: 1.991148, train acc: 0.479833, test acc: 0.485000
# Epoch 5/40, train loss: 1.876809, train acc: 0.540433, test acc: 0.544100
# Epoch 6/40, train loss: 1.760725, train acc: 0.590400, test acc: 0.597100
# Epoch 7/40, train loss: 1.644989, train acc: 0.633367, test acc: 0.643100
# Epoch 8/40, train loss: 1.531381, train acc: 0.674683, test acc: 0.684200
# Epoch 9/40, train loss: 1.422050, train acc: 0.712967, test acc: 0.719800
# Epoch 10/40, train loss: 1.318892, train acc: 0.742300, test acc: 0.749800
# Epoch 11/40, train loss: 1.223406, train acc: 0.765000, test acc: 0.773600
# Epoch 12/40, train loss: 1.136512, train acc: 0.782533, test acc: 0.789400
# Epoch 13/40, train loss: 1.058545, train acc: 0.795867, test acc: 0.803700
# Epoch 14/40, train loss: 0.989291, train acc: 0.806483, test acc: 0.813600
# Epoch 15/40, train loss: 0.928260, train acc: 0.814833, test acc: 0.821800
# Epoch 16/40, train loss: 0.874639, train acc: 0.821683, test acc: 0.826800
# Epoch 17/40, train loss: 0.827593, train acc: 0.827567, test acc: 0.832900
# Epoch 18/40, train loss: 0.786283, train acc: 0.832817, test acc: 0.838600
# Epoch 19/40, train loss: 0.749911, train acc: 0.836767, test acc: 0.843300
# Epoch 20/40, train loss: 0.717769, train acc: 0.841300, test acc: 0.847000
# Epoch 21/40, train loss: 0.689230, train acc: 0.844700, test acc: 0.850000
# Epoch 22/40, train loss: 0.663783, train acc: 0.848367, test acc: 0.853700
# Epoch 23/40, train loss: 0.640999, train acc: 0.851400, test acc: 0.855700
# Epoch 24/40, train loss: 0.620499, train acc: 0.854383, test acc: 0.859400
# Epoch 25/40, train loss: 0.601974, train acc: 0.857217, test acc: 0.862400
# Epoch 26/40, train loss: 0.585170, train acc: 0.859933, test acc: 0.865900
# Epoch 27/40, train loss: 0.569863, train acc: 0.862200, test acc: 0.867800
# Epoch 28/40, train loss: 0.555865, train acc: 0.864033, test acc: 0.869700
# Epoch 29/40, train loss: 0.543028, train acc: 0.865500, test acc: 0.871000
# Epoch 30/40, train loss: 0.531216, train acc: 0.867617, test acc: 0.872700
# Epoch 31/40, train loss: 0.520333, train acc: 0.868867, test acc: 0.874400
# Epoch 32/40, train loss: 0.510306, train acc: 0.871233, test acc: 0.875600
# Epoch 33/40, train loss: 0.501103, train acc: 0.871900, test acc: 0.876700
# Epoch 34/40, train loss: 0.492796, train acc: 0.873983, test acc: 0.875900
# Epoch 35/40, train loss: 0.485692, train acc: 0.872883, test acc: 0.877700
# Epoch 36/40, train loss: 0.480424, train acc: 0.871683, test acc: 0.873100
# Epoch 37/40, train loss: 0.478945, train acc: 0.862750, test acc: 0.868900
# Epoch 38/40, train loss: 0.484304, train acc: 0.843517, test acc: 0.847900
# Epoch 39/40, train loss: 0.506880, train acc: 0.823600, test acc: 0.826900
# Epoch 40/40, train loss: 0.546766, train acc: 0.800017, test acc: 0.801400

# %% [markdown]
# ### 3.2 SGD随机梯度下降

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# 获取MNIST数据集
def load_mnist():
    with open("../data/" + "mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]
X_train, y_train, X_test, y_test = load_mnist()

# 归一化处理
X_train = X_train / 255.0
X_test = X_test / 255.0

# 标准化处理
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# 将标签转化为one-hot向量
n_classes = 10
y_train = np.eye(n_classes)[y_train]
y_test = np.eye(n_classes)[y_test]

# 定义网络结构
input_size = X_train.shape[1]
hidden_size_1 = 128
hidden_size_2 = 64
output_size = n_classes

# 初始化权重和偏置 采用随机初始化
W1 = np.random.randn(input_size, hidden_size_1) / np.sqrt(input_size)
b1 = np.zeros(hidden_size_1)
W2 = np.random.randn(hidden_size_1, hidden_size_2) / np.sqrt(hidden_size_1)
b2 = np.zeros(hidden_size_2)
W3 = np.random.randn(hidden_size_2, output_size) / np.sqrt(hidden_size_2)
b3 = np.zeros(output_size)

# 定义激活函数和损失函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    exps = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return exps / np.sum(exps, axis=-1, keepdims=True)

def cross_entropy_loss(y_pred, y_true):
    n_samples = y_pred.shape[0]
    loss = -np.sum(y_true * np.log(y_pred + 1e-12)) / n_samples
    return loss

# 定义训练函数
def train(X, y_true, learning_rate):
    global W1, W2, W3, b1, b2, b3
    # 前向传播
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    m = y_true.shape[0]
    # 计算损失函数值和梯度
    loss = cross_entropy_loss(y_pred, y_true)

    grad_y_pred = y_pred - y_true

    grad_W3 = 1./m*np.dot(a2.T, grad_y_pred)
    grad_b3 = 1./m*np.sum(grad_y_pred, axis=0)
    grad_a2 = np.dot(grad_y_pred, W3.T)

    grad_z2 = grad_a2.copy()
    grad_z2[z2 < 0] = 0
    grad_W2 = 1./m*np.dot(a1.T, grad_z2)
    grad_b2 = 1./m*np.sum(grad_z2, axis=0)
    grad_a1 = np.dot(grad_z2, W2.T)

    grad_z1 = grad_a1.copy()
    grad_z1[z1 < 0] = 0
    grad_W1 = 1./m*np.dot(X.T, grad_z1)
    grad_b1 = 1./m*np.sum(grad_z1, axis=0)

    # 更新权重和偏置
    W3 -= learning_rate * grad_W3
    b3 -= learning_rate * grad_b3
    W2 -= learning_rate * grad_W2
    b2 -= learning_rate * grad_b2
    W1 -= learning_rate * grad_W1
    b1 -= learning_rate * grad_b1

    return loss

def predict(X):
    global W1, W2, W3, b1, b2, b3
    z1 = np.dot(X, W1) + b1
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = relu(z2)
    z3 = np.dot(a2, W3) + b3
    y_pred = softmax(z3)
    return np.argmax(y_pred, axis=-1)

learning_rate = 0.1
num_epochs = 40
batch_size = 8
num_batches = X_train.shape[0] // batch_size

train_loss_history = []
train_acc_history2 = []
test_acc_history2 = []
for epoch in range(num_epochs):
    # 在每个epoch前随机打乱训练数据
    permutation = np.random.permutation(X_train.shape[0])
    X_train = X_train[permutation]
    y_train = y_train[permutation]
    for i in range(num_batches):
        # 从训练数据中随机抽取一个batch
        X_batch = X_train[i * batch_size:(i + 1) * batch_size]
        y_batch = y_train[i * batch_size:(i + 1) * batch_size]
        if i%20 == 0:
            # 训练一个batch，并记录损失函数值
            loss = train(X_batch, y_batch, learning_rate)
            train_loss_history.append(loss)

    # 计算训练集和测试集上的精度
    train_acc = np.mean(predict(X_train) == np.argmax(y_train, axis=-1))
    test_acc = np.mean(predict(X_test) == np.argmax(y_test, axis=-1))
    train_acc_history2.append(train_acc)
    test_acc_history2.append(test_acc)

    # 输出训练进度
    print('Epoch %d/%d, train loss: %f, train acc: %f, test acc: %f' % (epoch+1, num_epochs, loss, train_acc, test_acc))


plt.plot(train_loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

plt.plot(train_acc_history2, label='train')
plt.plot(test_acc_history2, label='test')
plt.title('Classification Accuracy MBGD')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/40, train loss: 0.405750, train acc: 0.890017, test acc: 0.891200
# Epoch 2/40, train loss: 0.271129, train acc: 0.910633, test acc: 0.911400
# Epoch 3/40, train loss: 0.136457, train acc: 0.914667, test acc: 0.915900
# Epoch 4/40, train loss: 0.082008, train acc: 0.930733, test acc: 0.933300
# Epoch 5/40, train loss: 0.283065, train acc: 0.901867, test acc: 0.895600
# Epoch 6/40, train loss: 0.441922, train acc: 0.892717, test acc: 0.884700
# Epoch 7/40, train loss: 0.339603, train acc: 0.940117, test acc: 0.936300
# Epoch 8/40, train loss: 0.013312, train acc: 0.945417, test acc: 0.943900
# Epoch 9/40, train loss: 0.503141, train acc: 0.936033, test acc: 0.935100
# Epoch 10/40, train loss: 0.778122, train acc: 0.945733, test acc: 0.943300
# Epoch 11/40, train loss: 0.003812, train acc: 0.948550, test acc: 0.945500
# Epoch 12/40, train loss: 0.268090, train acc: 0.940383, test acc: 0.938000
# Epoch 13/40, train loss: 0.108647, train acc: 0.948350, test acc: 0.941800
# Epoch 14/40, train loss: 0.002152, train acc: 0.952283, test acc: 0.951100
# Epoch 15/40, train loss: 1.054822, train acc: 0.953233, test acc: 0.950300
# Epoch 16/40, train loss: 0.006705, train acc: 0.943850, test acc: 0.940400
# Epoch 17/40, train loss: 0.055184, train acc: 0.944250, test acc: 0.939000
# Epoch 18/40, train loss: 0.028090, train acc: 0.943667, test acc: 0.936500
# Epoch 19/40, train loss: 0.001066, train acc: 0.951683, test acc: 0.947200
# Epoch 20/40, train loss: 0.179811, train acc: 0.955650, test acc: 0.949900
# Epoch 21/40, train loss: 0.003643, train acc: 0.951600, test acc: 0.948200
# Epoch 22/40, train loss: 0.104050, train acc: 0.958917, test acc: 0.952300
# Epoch 23/40, train loss: 0.000418, train acc: 0.949667, test acc: 0.944000
# Epoch 24/40, train loss: 0.049495, train acc: 0.934867, test acc: 0.930400
# Epoch 25/40, train loss: 0.053548, train acc: 0.961100, test acc: 0.955300
# Epoch 26/40, train loss: 0.017709, train acc: 0.956650, test acc: 0.952700
# Epoch 27/40, train loss: 0.344866, train acc: 0.957450, test acc: 0.949900
# Epoch 28/40, train loss: 0.073686, train acc: 0.957033, test acc: 0.951000
# Epoch 29/40, train loss: 0.071929, train acc: 0.960550, test acc: 0.954600
# Epoch 30/40, train loss: 0.001584, train acc: 0.957067, test acc: 0.951400
# Epoch 31/40, train loss: 0.001125, train acc: 0.965983, test acc: 0.960100
# Epoch 32/40, train loss: 0.247505, train acc: 0.959517, test acc: 0.952200
# Epoch 33/40, train loss: 0.023056, train acc: 0.968100, test acc: 0.960200
# Epoch 34/40, train loss: 0.100972, train acc: 0.961850, test acc: 0.954600
# Epoch 35/40, train loss: 0.001776, train acc: 0.959550, test acc: 0.950900
# Epoch 36/40, train loss: 0.000179, train acc: 0.964150, test acc: 0.952100
# Epoch 37/40, train loss: 0.521531, train acc: 0.963400, test acc: 0.955800
# Epoch 38/40, train loss: 0.065618, train acc: 0.969383, test acc: 0.960900
# Epoch 39/40, train loss: 0.005457, train acc: 0.961367, test acc: 0.952100
# Epoch 40/40, train loss: 0.000019, train acc: 0.970100, test acc: 0.965100

# %% [markdown]
# ## 学习曲线对比

# %%
plt.plot(train_acc_history0, label='train-MBGD')
plt.plot(test_acc_history0, label='test-MBGD')
plt.plot(train_acc_history1, label='train-BGD')
plt.plot(test_acc_history1, label='test-BGD')
plt.plot(train_acc_history2, label='train-SGD')
plt.plot(test_acc_history2, label='test-SGD')
plt.title('BGD vs SGD')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('BGD vs SGD.png')
plt.show()
